# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data

df = pd.read_csv('Student_Placement_Career_Prediction_Dataset.csv')

# %%
df.head()
# Out:
#    student_id  age  gender      branch  cgpa  internship_count  project_count  \
# 0           1   23    Male          IT  8.99                 4              6
# 1           2   24  Female  Mechanical  8.36                 4              7
# 2           3   22  Female         EEE  7.18                 4              5
# 3           4   24  Female  Mechanical  6.28                 0              2
# 4           5   24  Female          IT  5.30                 3              4
#
#    certifications_count  coding_skills_score  communication_skills_score  \
# 0                     2                   41                          71
# 1                     5                   42                          64
# 2                     2                   84                          98
# 3                     4                   60                         100
# 4                     1                   78                          61
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   student_id                  10000 non-null  int64
#  1   age                         10000 non-null  int64
#  2   gender                      10000 non-null  object
#  3   branch                      10000 non-null  object
#  4   cgpa                        10000 non-null  float64
#  5   internship_count            10000 non-null  int64
#  6   project_count               10000 non-null  int64
#  7   certifications_count        10000 non-null  int64
#  8   coding_skills_score         10000 non-null  int64
#  9   communication_skills_score  10000 non-null  int64
#  10  soft_skills_score           10000 non-null  int64
#  11  hackathon_participation     10000 non-null  object
#  12  placement_status            10000 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# student_id                    0
# age                           0
# gender                        0
# branch                        0
# cgpa                          0
# internship_count              0
# project_count                 0
# certifications_count          0
# coding_skills_score           0
# communication_skills_score    0
# soft_skills_score             0
# hackathon_participation       0
# placement_status              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         student_id           age          cgpa  internship_count  \
# count  10000.00000  10000.000000  10000.000000      10000.000000
# mean    5000.50000     22.499900      7.520948          1.996500
# std     2886.89568      1.708711      1.447154          1.405591
# min        1.00000     20.000000      5.000000          0.000000
# 25%     2500.75000     21.000000      6.280000          1.000000
# 50%     5000.50000     23.000000      7.530000          2.000000
# 75%     7500.25000     24.000000      8.780000          3.000000
# max    10000.00000     25.000000     10.000000          4.000000
#
#        project_count  certifications_count  coding_skills_score  \
# count    10000.00000           10000.00000         10000.000000
# mean         4.01950               2.50910            70.026600
# std          2.00148               1.71657            17.485545
# min          1.00000               0.00000            40.000000
# ...

# %%
# Percentile Distributions
df['age'].quantile([0.1,0.25,0.5,0.75])
# Out:
# 0.10    20.0
# 0.25    21.0
# 0.50    23.0
# 0.75    24.0
# Name: age, dtype: float64

# %%
df['cgpa'].quantile([0.1,0.25,0.5,0.75])
# Out:
# 0.10    5.52
# 0.25    6.28
# 0.50    7.53
# 0.75    8.78
# Name: cgpa, dtype: float64

# %%
df['internship_count'].quantile([0.1,0.25,0.5,0.75])
# Out:
# 0.10    0.0
# 0.25    1.0
# 0.50    2.0
# 0.75    3.0
# Name: internship_count, dtype: float64

# %%
df['project_count'].quantile([0.1,0.25,0.5,0.75])
# Out:
# 0.10    1.0
# 0.25    2.0
# 0.50    4.0
# 0.75    6.0
# Name: project_count, dtype: float64

# %%
df['certifications_count'].quantile([0.1,0.25,0.5,0.75])
# Out:
# 0.10    0.0
# 0.25    1.0
# 0.50    3.0
# 0.75    4.0
# Name: certifications_count, dtype: float64

# %%
df['coding_skills_score'].quantile([0.1,0.25,0.5,0.75])
# Out:
# 0.10    46.0
# 0.25    55.0
# 0.50    70.0
# 0.75    85.0
# Name: coding_skills_score, dtype: float64

# %%
df['communication_skills_score'].quantile([0.1,0.25,0.5,0.75])
# Out:
# 0.10    46.0
# 0.25    55.0
# 0.50    70.0
# 0.75    85.0
# Name: communication_skills_score, dtype: float64

# %%
df['soft_skills_score'].quantile([0.1,0.25,0.5,0.75])
# Out:
# 0.10    45.0
# 0.25    55.0
# 0.50    70.0
# 0.75    85.0
# Name: soft_skills_score, dtype: float64

# %%
# Analysis of Categorial Columns
df['gender'].value_counts()
df['gender'].nunique()
# Out:
# 2

# %%
df['branch'].value_counts()
df['branch'].nunique()
# Out:
# 6

# %%
df['hackathon_participation'].value_counts()
df['hackathon_participation'].nunique()
# Out:
# 2

# %%
df['placement_status'].value_counts()
df['placement_status'].nunique()
# Out:
# 2

# %%
# Comparsions

# Grouping placement status by age
df.groupby('placement_status')['age'].agg(['mean', 'median', 'count'])
# Out:
#                        mean  median  count
# placement_status
# Not Placed        22.501421    23.0   4926
# Placed            22.498423    23.0   5074

# %%
# Grouping placement status by cgpa
df.groupby('placement_status')['cgpa'].agg(['mean', 'median', 'min', 'max'])
# Out:
#                       mean  median  min   max
# placement_status
# Not Placed        6.806429    6.58  5.0  10.0
# Placed            8.214626    8.44  5.0  10.0

# %%
# Grouping placement status by number of internerships
df.groupby('placement_status')['internship_count'].agg(['mean', 'median', 'min', 'max'])
# Out:
#                       mean  median  min  max
# placement_status
# Not Placed        1.451888     1.0    0    4
# Placed            2.525227     3.0    0    4

# %%
# Grouping placement status by number of projects
df.groupby('placement_status')['project_count'].agg(['mean', 'median', 'min', 'max'])
# Out:
#                       mean  median  min  max
# placement_status
# Not Placed        3.411896     3.0    1    7
# Placed            4.609381     5.0    1    7

# %%
# Grouping placement status by number of certifications
df.groupby('placement_status')['certifications_count'].agg(['mean', 'median', 'min', 'max'])
# Out:
#                       mean  median  min  max
# placement_status
# Not Placed        1.923264     2.0    0    5
# Placed            3.077848     3.0    0    5

# %%
# Grouping placement status by coding skills score
df.groupby('placement_status')['coding_skills_score'].agg(['mean', 'median', 'min', 'max'])
# Out:
#                        mean  median  min  max
# placement_status
# Not Placed        67.270402    66.0   40  100
# Placed            72.702404    74.0   40  100

# %%
# Grouping placement status by number of communications
df.groupby('placement_status')['communication_skills_score'].agg(['mean', 'median', 'min', 'max'])
# Out:
#                        mean  median  min  max
# placement_status
# Not Placed        67.973609    67.0   40  100
# Placed            71.810800    73.0   40  100

# %%
# Grouping placement status by number of soft skills
df.groupby('placement_status')['soft_skills_score'].agg(['mean', 'median', 'min', 'max'])
# Out:
#                        mean  median  min  max
# placement_status
# Not Placed        68.452294    68.0   40  100
# Placed            71.618447    72.0   40  100

# %%
# Asociation between hackathon participation and their placement status
pd.crosstab(df['hackathon_participation'], df['placement_status'])
# Out:
# placement_status         Not Placed  Placed
# hackathon_participation
# No                             2848    2089
# Yes                            2078    2985

# %%
# Asociation between branch and their placement status
pd.crosstab(df['branch'], df['placement_status'])
# Out:
# placement_status  Not Placed  Placed
# branch
# CSE                      829     874
# Civil                    835     836
# ECE                      812     807
# EEE                      818     838
# IT                       833     887
# Mechanical               799     832

# %%
# Asociation between gender and their placement status
pd.crosstab(df['gender'], df['placement_status'])
# Out:
# placement_status  Not Placed  Placed
# gender
# Female                  2442    2574
# Male                    2484    2500

# %%
# Visualizations

# Histogram
df['internship_count'].hist()
# Out:
# <Axes: >

# %%
# Bar chart of branch of education
df['placement_status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='placement_status'>

# %%
# Boxplot grouped by the number of interships and placement status
df.boxplot(column='internship_count', by='placement_status')
# Out:
# <Axes: title={'center': 'internship_count'}, xlabel='placement_status'>

# %%
# Correlation Heatmap
df.corr(numeric_only=True).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_eb0e4_row0_col0, #T_eb0e4_row1_col1, #T_eb0e4_row2_col2, #T_eb0e4_row3_col3, #T_eb0e4_row4_col4, #T_eb0e4_row5_col5, #T_eb0e4_row6_col6, #T_eb0e4_row7_col7, #T_eb0e4_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_eb0e4_row0_col1, #T_eb0e4_row2_col5, #T_eb0e4_row2_col6, #T_eb0e4_row3_col1, #T_eb0e4_row3_col4, #T_eb0e4_row3_col7, #T_eb0e4_row6_col0, #T_eb0e4_row6_col3, #T_eb0e4_row6_col7, #T_eb0e4_row7_col3, #T_eb0e4_row8_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_eb0e4_row0_col2, #T_eb0e4_row5_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_eb0e4_row0_col3, #T_eb0e4_row1_col3, #T_eb0e4_row2_col8, #T_eb0e4_row4_col3, #T_eb0e4_row4_col5, #T_eb0e4_row6_col2, #T_eb0e4_row8_col0, #T_eb0e4_row8_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# ...

# %%
# Results

# 5074 students have received a placement and 4926 students did not get placed.
# 2442 Female student got placed and 2574 did not get placed.
# 2484 Male	students got placed and	2500 did not get placed.
# 23 is the average age of students who received a placement.
# Students with a cgpa of 8.0 or higher received a placement, 6.0 or lower cgpa students did not get placed.
# Students with 2 or more internships got placed, 1 or less internships did not get placed.
# Students with 4 or more personal projects received a placement, while 3 or less did not get placed.
# Students with 3 or more certifications received a placement, while 2 or less did not get placed.
# Students with a coding score of 72 or more received a placement, while 71 or less did not get placed.
# Students with a communication score of 71 or more received a placement, while 70 or less did not get placed.
# Students with a soft skill score of 71 or more received a placement, while 70 or less did not get placed.
